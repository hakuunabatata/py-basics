# %%
for i in range(10):
    print(f'O numero é {i}')
# Out:
# O numero é 0
# O numero é 1
# O numero é 2
# O numero é 3
# O numero é 4
# O numero é 5
# O numero é 6
# O numero é 7
# O numero é 8
# O numero é 9

# %%
frutas = ['banana','maçã','laranja','limão']

for fruta in frutas:
    print(f'Fruta: {fruta}')
# Out:
# Fruta: banana
# Fruta: maçã
# Fruta: laranja
# Fruta: limão

# %%
for i in range(500):
    if (i%2 == 0):
        print(f'{i} é par')
    else:
        print(f'{i} é impar')
# Out:
# 0 é par
# 1 é impar
# 2 é par
# 3 é impar
# 4 é par
# 5 é impar
# 6 é par
# 7 é impar
# 8 é par
# 9 é impar
# 10 é par
# 11 é impar
# 12 é par
# 13 é impar
# 14 é par
# 15 é impar
# 16 é par
# 17 é impar
# 18 é par
# 19 é impar
# 20 é par
# 21 é impar
# 22 é par
# 23 é impar
# 24 é par
# 25 é impar
# 26 é par
# 27 é impar
# 28 é par
# 29 é impar
# 30 é par
# 31 é impar
# 32 é par
# 33 é impar
# 34 é par
# 35 é impar
# 36 é par
# 37 é impar
# 38 é par
# 39 é impar
# 40 é par
# 41 é impar
# 42 é par
# 43 é impar
# 44 é par
# 45 é impar
# 46 é par
# 47 é impar
# 48 é par
# 49 é impar
# 50 é par
# 51 é impar
# 52 é par
# 53 é impar
# 54 é par
# 55 é impar
# 56 é par
# 57 é impar
# 58 é par
# 59 é impar
# 60 é par
# 61 é impar
# 62 é par
# 63 é impar
# 64 é par
# 65 é impar
# 66 é par
# 67 é impar
# 68 é par
# 69 é impar
# 70 é par
# 71 é impar
# 72 é par
# 73 é impar
# 74 é par
# 75 é impar
# 76 é par
# 77 é impar
# 78 é par
# 79 é impar
# 80 é par
# 81 é impar
# 82 é par
# 83 é impar
# ...
